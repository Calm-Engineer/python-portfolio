# %% [markdown]
# Que 1. Is this code correctly indented? If not, explain the error and correct it.

# %%
if 10 > 5:
print("Ten is greater than five!")

# No, the print statement needs to be indented with at lease 1 space since it's inside the if block. 
# In Python, indentation is crucial as it defines code blocks. We usually keep 1 tab indent.
# Out:
#   Cell In[1], line 2
#     print("Ten is greater than five!")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 10 > 5:
    print("Ten is greater than five!")
# Out:
# Ten is greater than five!

# %% [markdown]
# Que 2.Does this code have the correct indentation? Why or why not?

# %%
if 7 > 2:
    print("Seven is greater than two!")

# Yes since it is indented with a tab
# Out:
# Seven is greater than two!

# %% [markdown]
# Que 3.Identify the problem in this code and correct it.

# %%
if 3 == 3:
    print("Three equals three.")
else:
print("This is not true.")
# Out:
#   Cell In[4], line 4
#     print("This is not true.")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 3

# %%
if 3 == 3:    # 3==3 asks "is 3 equal to 3?"
    print("Three equals three.")
else:
    print("This is not true.")
# Out:
# Three equals three.

# %% [markdown]
# Que 4.Explain the issue with indentation and correct the code.

# %%
if 5 > 3:
    print("Five is greater than three.")
    if 2 < 4:
    print("Nested condition is true.")

# Need to indent the print function after the 2nd if statement since the 2nd print statement belongs to the 2nd if statement
# Out:
#   Cell In[9], line 4
#     print("Nested condition is true.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
if 5 > 3:
    print("Five is greater than three.")
    if 2 < 4:
        print("Nested condition is true.")
# Out:
# Five is greater than three.
# Nested condition is true.

# %% [markdown]
# Que 5.What's wrong with the indentation in this example?

# %%
if 6 != 10:
    print("Six is not equal to ten.")
 else:
    print("Six equals ten.")
     
# if and else need to be in the same line
# Out:
#   File <string>:3
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
if 6 != 10:
    print("Six is not equal to ten.")
else:
    print("Six equals ten.")
# Out:
# Six is not equal to ten.

# %% [markdown]
# Que 6 Is this code properly indented?If not correct it

# %%
if 4 == 4:
    print("Four equals four.")
else:
    print("This won't print.")

# correctly intended
# Out:
# Four equals four.

# %% [markdown]
# Que 7. Correct the indentation errors in this code.

# %%
if 1 < 2:
    print("First condition is true.")
if 2 < 3:
    print("Second condition is true.")
else:
    print("Else block here.")

# correctly intended
# Out:
# First condition is true.
# Second condition is true.

# %% [markdown]
# Que 8.What's wrong with this code? Fix the indentation.

# %%
if 9 > 8:
    print("Nine is greater than eight.")
        print("This line will cause an error.")

# both print statements are not aligned. Have not intended same distance
# Out:
#   Cell In[16], line 3
#     print("This line will cause an error.")
#     ^
# IndentationError: unexpected indent

# %%
if 9 > 8:
    print("Nine is greater than eight.")
    print("This line will cause an error.")
# Out:
# Nine is greater than eight.
# This line will cause an error.

# %% [markdown]
# Que 9. Correct the indentation of this code and explain why it was wrong.

# %%
if 5 == 5:
    print("Five equals five.")
   else:
    print("This is not true.")

# if and else need to be aligned
# Out:
#   File <string>:3
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
if 5 == 5:
    print("Five equals five.")
else:
    print("This is not true.")
# Out:
# Five equals five.

# %% [markdown]
# Que 10.Identify and fix the indentation issue.

# %%
if 8 > 6:
    if 7 > 4:
        print("Both conditions are true.")
    else:
    print("The second condition is false.")

# 2nd print statement need to get intended so that it aligns with the 1st print statement
# Out:
#   Cell In[21], line 5
#     print("The second condition is false.")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 4

# %%
if 8 > 6:
    if 7 > 4:
        print("Both conditions are true.")
    else:
        print("The second condition is false.")
# Out:
# Both conditions are true.

# %% [markdown]
# Que 11.Is the final print statement correctly indented?

# %%
if 10 < 20:
    print("Ten is less than twenty.")
    print("This statement should also print.")
else:
    print("This statement should not print.")
 print("This statement is outside the block.")

# 4th print statement need to get intended with other 3 print statements
# Out:
#   File <string>:6
#     print("This statement is outside the block.")
#                                                  ^
# IndentationError: unindent does not match any outer indentation level

# %%
if 10 < 20:
    print("Ten is less than twenty.")
    print("This statement should also print.")
else:
    print("This statement should not print.")
    print("This statement is outside the block.")
# Out:
# Ten is less than twenty.
# This statement should also print.

# %% [markdown]
# Que 12.What is wrong with the indentation in this code?

# %%
if 2 == 2:
    print("First line of block")
  print("Second line of block")

# 2nd print statement need to be aligned with the 1st print statement
# Out:
#   Cell In[31], line 3
#     print("Second line of block")
#     ^
# IndentationError: unexpected indent

# %%
if 2 == 2:
    print("First line of block")
    print("Second line of block")
# Out:
# First line of block
# Second line of block

# %% [markdown]
# Que 13.Correct the indentation of the else statement.

# %%
if 15 > 10:
    print("Fifteen is greater than ten.")
else:
print("This statement is misaligned.")

# 2nd print statement need to be aligned with the 1st print statement after else statement
# Out:
#   Cell In[33], line 4
#     print("This statement is misaligned.")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 3

# %%
if 15 > 10:
    print("Fifteen is greater than ten.")
else:
    print("This statement is misaligned.")
# Out:
# Fifteen is greater than ten.

# %% [markdown]
# Que 14.Fix the indentation for proper alignment of the else block.

# %%
if 3 < 4:
    print("Three is less than four.")
else:
  print("This statement is inside the else block.")

# The above works without any error but for the clarity of proper coding 2nd print statement need to be aligned with the 1st print statement.
# Out:
# Three is less than four.

# %%
if 3 < 4:
    print("Three is less than four.")
else:
    print("This statement is inside the else block.")
# Out:
# Three is less than four.

# %% [markdown]
# Que 15.Does this code have correct indentation?

# %%
if 6 < 9:
    print("Six is less than nine.")
    if 3 < 5:
        print("Three is less than five.")
else:
    print("This is the else block.")

# Yes indentations of both if blocks are correct
# Out:
# Six is less than nine.
# Three is less than five.

# %% [markdown]
# Que 16.Identify and correct the indentation issues.

# %%
if 8 >= 8:
    print("Eight is equal or greater.")
   if 10 > 5:
    print("Ten is greater.")
else:
    print("This is the else block.")

# 2nd print and if statements need to have the correct indentation
# Out:
#   File <string>:3
#     if 10 > 5:
#               ^
# IndentationError: unindent does not match any outer indentation level

# %%
if 8 >= 8:
    print("Eight is equal or greater.")
    if 10 > 5:
        print("Ten is greater.")
else:
    print("This is the else block.")
# Out:
# Eight is equal or greater.
# Ten is greater.

# %% [markdown]
# Que 17.What's wrong with this code?

# %%
if 20 <= 20:
    print("Twenty is less than or equal to twenty.")
     else:
    print("This will cause an error.")

# else statement need to be aligned with the if statement
# Out:
#   Cell In[47], line 3
#     else:
#     ^
# IndentationError: unexpected indent

# %%
if 20 <= 20:
    print("Twenty is less than or equal to twenty.")
else:
    print("This will cause an error.")
# Out:
# Twenty is less than or equal to twenty.

# %% [markdown]
# Que 18.Is this code properly indented? Why or why not?

# %%
if 12 == 12:
    print("Twelve equals twelve.")
    if 5 > 2:
        print("Nested if statement.")
    else:
        print("Nested else statement.")
else:
    print("This is the outer else block.")

# Yes it is properly intended
# Out:
# Twelve equals twelve.
# Nested if statement.

# %% [markdown]
# Que 19. Correct the indentation error in the nested block.

# %%
if 9 != 1:
    if 4 > 2:
        print("Nested if block.")
    else:
    print("This should be indented.")
else:
    print("Outer else block.")

# 2nd print statement need indentation
# Out:
#   Cell In[51], line 5
#     print("This should be indented.")
#     ^
# IndentationError: expected an indented block after 'else' statement on line 4

# %%
if 9 != 1:
    if 4 > 2:
        print("Nested if block.")
    else:
        print("This should be indented.")
else:
    print("Outer else block.")
# Out:
# Nested if block.

# %% [markdown]
# Que 20.Where is the indentation error, and how can you fix it?

# %%
if 5 < 10:
    print("Five is less than ten.")
else:
    print("This is the else block.")
  print("This line is outside the block.")

# 3rd print statement should be intended
# Out:
#   File <string>:5
#     print("This line is outside the block.")
#                                             ^
# IndentationError: unindent does not match any outer indentation level

# %%
if 5 < 10:
    print("Five is less than ten.")
else:
    print("This is the else block.")
    print("This line is outside the block.")
# Out:
# Five is less than ten.
