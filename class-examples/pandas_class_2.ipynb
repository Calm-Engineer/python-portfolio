# %%
import pandas as pd

# %%
df=pd.read_csv('UP_2022 (2).csv')

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  Total Votes  % of Votes  \
# 0      1  Umar Ali Khan           Samajwadi Party       134513       47.81
# 1      1   Naresh Saini    Bharatiya Janata Party        96633       34.34
# 2      1     Rais Malik       Bahujan Samaj Party        45075       16.02
# 3      1  Poonam Kamboj  Indian National Congress         1632        0.58
# 4      1   Sushil Kumar           Aam Aadmi Party         1162        0.41
#
#    Rank
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
df.tail()
# Out:
#       ac_no     Candidate                               Party  Total Votes  \
# 4840    403  HRIDAY KUMAR                         Independent         1853
# 4841    403   ASHOK KUMAR                   Jan Adhikar Party         1758
# 4842    403    MISHRI LAL                         Independent         1317
# 4843    403  KRIPASHANKAR  All India Peoples' Front (Radical)          894
# 4844    403   PUSHPA DEVI                     Aam Aadmi Party          830
#
#       % of Votes  Rank
# 4840        0.91     7
# 4841        0.86     8
# 4842        0.64     9
# 4843        0.44    10
# 4844        0.41    11

# %%
df.describe()
# Out:
#              ac_no    Total Votes   % of Votes         Rank
# count  4845.000000    4845.000000  4845.000000  4845.000000
# mean    205.436533   19022.269556     8.317882     6.815067
# std     116.378667   35774.657909    15.358766     3.984598
# min       1.000000      49.000000     0.020000     1.000000
# 25%     103.000000     531.000000     0.230000     4.000000
# 50%     209.000000    1185.000000     0.530000     7.000000
# 75%     307.000000   11396.000000     5.170000    10.000000
# max     403.000000  322882.000000    70.160000    26.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4845 entries, 0 to 4844
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ac_no        4845 non-null   int64
#  1   Candidate    4845 non-null   object
#  2   Party        4845 non-null   object
#  3   Total Votes  4845 non-null   int64
#  4   % of Votes   4845 non-null   float64
#  5   Rank         4845 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 227.2+ KB

# %%
df['Candidate']
# Out:
# 0       Umar Ali Khan
# 1        Naresh Saini
# 2          Rais Malik
# 3       Poonam Kamboj
# 4        Sushil Kumar
#             ...
# 4840     HRIDAY KUMAR
# 4841      ASHOK KUMAR
# 4842       MISHRI LAL
# 4843     KRIPASHANKAR
# 4844      PUSHPA DEVI
# Name: Candidate, Length: 4845, dtype: object

# %%
type(df['Candidate'])
# Out:
# pandas.core.series.Series

# %%
df[['Candidate']]
# Out:
#           Candidate
# 0     Umar Ali Khan
# 1      Naresh Saini
# 2        Rais Malik
# 3     Poonam Kamboj
# 4      Sushil Kumar
# ...             ...
# 4840   HRIDAY KUMAR
# 4841    ASHOK KUMAR
# 4842     MISHRI LAL
# 4843   KRIPASHANKAR
# 4844    PUSHPA DEVI
#
# [4845 rows x 1 columns]

# %%
type(df[['Candidate']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Candidate','Rank']]
# Out:
#           Candidate  Rank
# 0     Umar Ali Khan     1
# 1      Naresh Saini     2
# 2        Rais Malik     3
# 3     Poonam Kamboj     4
# 4      Sushil Kumar     5
# ...             ...   ...
# 4840   HRIDAY KUMAR     7
# 4841    ASHOK KUMAR     8
# 4842     MISHRI LAL     9
# 4843   KRIPASHANKAR    10
# 4844    PUSHPA DEVI    11
#
# [4845 rows x 2 columns]

# %%
df[df['Rank']==1]
# Out:
#       ac_no              Candidate                   Party  Total Votes  \
# 0         1          Umar Ali Khan         Samajwadi Party       134513
# 9         2       MUKESH CHOUDHARY  Bharatiya Janata Party       104114
# 21        3          RAJEEV GUMBER  Bharatiya Janata Party       143195
# 34        4             Ashu Malik         Samajwadi Party       107007
# 49        5                BRIJESH  Bharatiya Janata Party        93890
# ...     ...                    ...                     ...          ...
# 4786    399     RAMA SHANKAR SINGH  Bharatiya Janata Party       105377
# 4801    400  Dr. Anil Kumar Maurya  Bharatiya Janata Party       101277
# 4814    401        Bhupesh Chaubey  Bharatiya Janata Party        84496
# 4825    402          SANJEEV KUMAR  Bharatiya Janata Party        78364
# 4834    403               RAMDULAR  Bharatiya Janata Party        84407
#
#       % of Votes  Rank
# 0          47.81     1
# 9          38.47     1
# 21         48.85     1
# ...

# %%
df[df.Rank==1]
# Out:
#       ac_no              Candidate                   Party  Total Votes  \
# 0         1          Umar Ali Khan         Samajwadi Party       134513
# 9         2       MUKESH CHOUDHARY  Bharatiya Janata Party       104114
# 21        3          RAJEEV GUMBER  Bharatiya Janata Party       143195
# 34        4             Ashu Malik         Samajwadi Party       107007
# 49        5                BRIJESH  Bharatiya Janata Party        93890
# ...     ...                    ...                     ...          ...
# 4786    399     RAMA SHANKAR SINGH  Bharatiya Janata Party       105377
# 4801    400  Dr. Anil Kumar Maurya  Bharatiya Janata Party       101277
# 4814    401        Bhupesh Chaubey  Bharatiya Janata Party        84496
# 4825    402          SANJEEV KUMAR  Bharatiya Janata Party        78364
# 4834    403               RAMDULAR  Bharatiya Janata Party        84407
#
#       % of Votes  Rank
# 0          47.81     1
# 9          38.47     1
# 21         48.85     1
# ...

# %%
df[(df['Party']=='Bharatiya Janata Party') & (df['Rank']==1)]['ac_no'].count()
# Out:
# 255

# %%
df.sort_values(['Total Votes'],ascending=True) #asc
df.sort_values(['Total Votes'],ascending=False) #desc
# Out:
#       ac_no                     Candidate                        Party  \
# 564      48                    KANAK JAIN                   Mihir Sena
# 2021    174              DHARMENDRA GUPTA   Voters Party International
# 2007    173  Naimish Pratap Narayan Singh  Rashtriya Rashtrawadi Party
# 2472    214                   GUDDI DIXIT      RASHTRIYA VIKLANG PARTY
# 1228    104                 Omendra Singh                  Independent
# ...     ...                           ...                          ...
# 2615    226             Ramratan Kushwaha       Bharatiya Janata Party
# 2627    227                   Manohar Lal       Bharatiya Janata Party
# 717      62            TEJPAL SINGH NAGAR       Bharatiya Janata Party
# 703      61                  Pankaj Singh       Bharatiya Janata Party
# 630      55            SUNIL KUMAR SHARMA       Bharatiya Janata Party
#
#       Total Votes  % of Votes  Rank
# 564            49        0.02    13
# 2021           63        0.03    14
# ...

# %%
df['Party'].unique()
# Out:
# array(['Samajwadi Party', 'Bharatiya Janata Party', 'Bahujan Samaj Party',
#        'Indian National Congress', 'Aam Aadmi Party', 'None of the Above',
#        'Independent', 'All India Majlis-E-Ittehadul Muslimeen',
#        'Aazad Samaj Party (Kanshi Ram)', 'Inqalab Vikas Dal',
#        'Jai Maha Bharath Party', 'Aamjan Ekta Party', 'Lok Dal',
#        'Akhand Bharat Vikas Party', 'Bahujan Mukti Party',
#        'Sanyukt Vikas Party', 'Log Party',
#        'Bharatrashtra Democratic Party', 'Jansatta Party',
#        'Rashtriya Lok Dal', 'India Janshakti Party',
#        'SOCIAL DEMOCRATIC PARTY OF INDIA', 'Sarvjan Lok Shakti Party',
#        'Jai Samta Party', 'Rashtriya Samaj Paksha',
#        'Majdoor Kisan Union Party', 'Bharat Lok Sewak Party',
#        'Bharatiya Sarvodaya Kranti Party', 'Shiv Sena',
#        'Pichhra Samaj Party', 'Rashtra Nirman Party',
#        'Rashtriya Samaj Dal (R)', 'Gareeb Kranti Party',
# ...

# %%
df['Party'].nunique()
# Out:
# 289

# %%
df['Total Votes'].mean()
# Out:
# 19022.26955624355

# %%
df['square_col']=df['Rank']**2

# %%
df['col1']=(df['Total Votes']*df['% of Votes']).round(1)

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  Total Votes  % of Votes  \
# 0      1  Umar Ali Khan           Samajwadi Party       134513       47.81
# 1      1   Naresh Saini    Bharatiya Janata Party        96633       34.34
# 2      1     Rais Malik       Bahujan Samaj Party        45075       16.02
# 3      1  Poonam Kamboj  Indian National Congress         1632        0.58
# 4      1   Sushil Kumar           Aam Aadmi Party         1162        0.41
#
#    Rank  square_col       col1
# 0     1           1  6431066.5
# 1     2           4  3318377.2
# 2     3           9   722101.5
# 3     4          16      946.6
# 4     5          25      476.4

# %%
df[df['Rank']==1].drop_duplicates(['ac_no'],keep='last')
# Out:
#       ac_no              Candidate                   Party  Total Votes  \
# 0         1          Umar Ali Khan         Samajwadi Party       134513
# 9         2       MUKESH CHOUDHARY  Bharatiya Janata Party       104114
# 21        3          RAJEEV GUMBER  Bharatiya Janata Party       143195
# 34        4             Ashu Malik         Samajwadi Party       107007
# 49        5                BRIJESH  Bharatiya Janata Party        93890
# ...     ...                    ...                     ...          ...
# 4786    399     RAMA SHANKAR SINGH  Bharatiya Janata Party       105377
# 4801    400  Dr. Anil Kumar Maurya  Bharatiya Janata Party       101277
# 4814    401        Bhupesh Chaubey  Bharatiya Janata Party        84496
# 4825    402          SANJEEV KUMAR  Bharatiya Janata Party        78364
# 4834    403               RAMDULAR  Bharatiya Janata Party        84407
#
#       % of Votes  Rank  square_col       col1
# 0          47.81     1           1  6431066.5
# ...

# %%
df=df.rename(columns={'Total Votes':'total_votes','% of Votes':'perc_votes'})

# %%
df.rename(columns={'Total Votes':'total_votes','% of Votes':'perc_votes'},inplace=True)

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  total_votes  perc_votes  \
# 0      1  Umar Ali Khan           Samajwadi Party       134513       47.81
# 1      1   Naresh Saini    Bharatiya Janata Party        96633       34.34
# 2      1     Rais Malik       Bahujan Samaj Party        45075       16.02
# 3      1  Poonam Kamboj  Indian National Congress         1632        0.58
# 4      1   Sushil Kumar           Aam Aadmi Party         1162        0.41
#
#    Rank  square_col       col1
# 0     1           1  6431066.5
# 1     2           4  3318377.2
# 2     3           9   722101.5
# 3     4          16      946.6
# 4     5          25      476.4

# %%
pd.read_csv()
.head()
.tail()
info()
describe()
sort_values()
drop_duplicates()
rename()
creating new columns
applying filter in data
type
round
mean
unique()
nunique()

group by 
pivot 
loc
iloc
count()
fillna()
dtypes
astype()
reset_index()
set_option()
isin()

# %%
# df.groupby(['Party'])['Candidate'].count()

# %%
349/403
# Out:
# 0.8660049627791563

# %%
x=tuple(df[df['Rank']==1].groupby(['Party'])['Candidate'].count().reset_index()['Party'])

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
for only those parties who have won atleast one seat , show me party name in rows  and rank in columns

# %%
df1=df[df['Party'].isin(x)].groupby(['Party','Rank'])['ac_no'].count().reset_index()

# %%
df1.pivot(index='Rank',columns='Party',values='ac_no').reset_index().fillna('')
# Out:
# Party  Rank Apna Dal (Soneylal) Bahujan Samaj Party Bharatiya Janata Party  \
# 0         1                12.0                 1.0                  255.0
# 1         2                 5.0                18.0                  115.0
# 2         3                                   348.0                    5.0
# 3         4                                    34.0                    1.0
# 4         5                                     2.0
# 5         6
# 6         7
# 7         8
# 8         9
# 9        10
# 10       11
# 11       12
# 12       13
# 13       14
# 14       16
#
# Party Indian National Congress Jansatta Dal Loktantrik  \
# 0                          2.0                     2.0
# 1                          4.0
# 2                         25.0
# 3                        194.0                     2.0
# 4                        106.0                     2.0
# 5                         44.0
# 6                         21.0                     1.0
# ...

# %%
df.dtypes
# Out:
# ac_no            int64
# Candidate       object
# Party           object
# total_votes      int64
# perc_votes     float64
# Rank             int64
# square_col       int64
# col1           float64
# dtype: object

# %%
df['perc_votes']=df['perc_votes'].astype(int)

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  total_votes  perc_votes  \
# 0      1  Umar Ali Khan           Samajwadi Party       134513          47
# 1      1   Naresh Saini    Bharatiya Janata Party        96633          34
# 2      1     Rais Malik       Bahujan Samaj Party        45075          16
# 3      1  Poonam Kamboj  Indian National Congress         1632           0
# 4      1   Sushil Kumar           Aam Aadmi Party         1162           0
#
#    Rank  square_col       col1
# 0     1           1  6431066.5
# 1     2           4  3318377.2
# 2     3           9   722101.5
# 3     4          16      946.6
# 4     5          25      476.4

# %%
.loc
.iloc

# %%
df.loc[df['Rank']==1, 'winning_col']='winner'

# %%
df['winning_col']=df['winning_col'].fillna('others')

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  total_votes  perc_votes  \
# 0      1  Umar Ali Khan           Samajwadi Party       134513          47
# 1      1   Naresh Saini    Bharatiya Janata Party        96633          34
# 2      1     Rais Malik       Bahujan Samaj Party        45075          16
# 3      1  Poonam Kamboj  Indian National Congress         1632           0
# 4      1   Sushil Kumar           Aam Aadmi Party         1162           0
#
#    Rank  square_col       col1 winning_col
# 0     1           1  6431066.5      winner
# 1     2           4  3318377.2      others
# 2     3           9   722101.5      others
# 3     4          16      946.6      others
# 4     5          25      476.4      others

# %%
df.loc[df['Party']=='Samajwadi Party','Party']='SP'

# %%
df.head()
# Out:
#    ac_no      Candidate                     Party  total_votes  perc_votes  \
# 0      1  Umar Ali Khan                        SP       134513          47
# 1      1   Naresh Saini    Bharatiya Janata Party        96633          34
# 2      1     Rais Malik       Bahujan Samaj Party        45075          16
# 3      1  Poonam Kamboj  Indian National Congress         1632           0
# 4      1   Sushil Kumar           Aam Aadmi Party         1162           0
#
#    Rank  square_col       col1 winning_col
# 0     1           1  6431066.5      winner
# 1     2           4  3318377.2      others
# 2     3           9   722101.5      others
# 3     4          16      946.6      others
# 4     5          25      476.4      others

# %%
df['total_votes'].iloc[1]
# Out:
# 96633

# %%
group by 
pivot 
loc
iloc
count()
fillna()
dtypes
astype()
reset_index()
set_option()
isin()
